# %% [markdown]
# # About
#
# This notebook
# - converts Skills.xlsx into Skills.csv
# - outputs soc_mapping.csv
# - outputs skills_importance.csv
# - outputs skill_based_risk.csv

# %%
import pandas as pd
import numpy as np

# %%
TECH_INTENSITY_PATH = '../data/tech_intensity_simple.csv'

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # soc_mapping.csv

# %%
import json

# Read the SOC mapping JSON file
with open('../data/soc_mapping.json', 'r') as f:
    soc_mapping = json.load(f)

df = pd.DataFrame.from_dict(soc_mapping, orient='index')

# Reset index to make the SOC codes a column
df = df.reset_index()
df = df.rename(columns={'index': 'SOC Code'})
# First remove the hyphen, then take the appropriate number of digits
df['normalized_SOC_Code'] = df['SOC Code'].str.replace('-', '')
df['normalized_major_code'] = df['SOC Code'].str.replace('-', '').str[:2]
df['normalized_minor_code'] = df['SOC Code'].str.replace('-', '').str[:3]
df['normalized_broad_code'] = df['SOC Code'].str.replace('-', '').str[:4]

print("\nColumns in the DataFrame:")
print(df.columns.tolist())
# Out:
# Columns in the DataFrame:
# ['SOC Code', 'detailed_title', 'major_code', 'major_title', 'minor_code', 'minor_title', 'broad_code', 'broad_title', 'normalized_SOC_Code', 'normalized_major_code', 'normalized_minor_code', 'normalized_broad_code']

# %%
# df.to_csv('../data/soc_mapping.csv', index=False)

# %% [markdown]
# # skills.csv

# %%
skills_df = pd.read_excel('../data/ONET/Skills.xlsx')

# %%
skills_df.head()
# Out:
#   O*NET-SOC Code             Title Element ID           Element Name Scale ID  \
# 0     11-1011.00  Chief Executives    2.A.1.a  Reading Comprehension       IM
# 1     11-1011.00  Chief Executives    2.A.1.a  Reading Comprehension       LV
# 2     11-1011.00  Chief Executives    2.A.1.b       Active Listening       IM
# 3     11-1011.00  Chief Executives    2.A.1.b       Active Listening       LV
# 4     11-1011.00  Chief Executives    2.A.1.c                Writing       IM
#
#    Scale Name  Data Value  N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0  Importance        4.12  8          0.1250          3.8800          4.3700
# 1       Level        4.62  8          0.1830          4.2664          4.9836
# 2  Importance        4.00  8          0.0000          4.0000          4.0000
# 3       Level        4.75  8          0.1637          4.4292          5.0708
# 4  Importance        4.12  8          0.1250          3.8800          4.3700
#
#   Recommend Suppress Not Relevant     Date Domain Source
# 0                  N          NaN  08/2023       Analyst
# 1                  N            N  08/2023       Analyst
# 2                  N          NaN  08/2023       Analyst
# 3                  N            N  08/2023       Analyst
# 4                  N          NaN  08/2023       Analyst

# %%
# print unique values of Element Name
print(f"unique count of Element Name: {len(skills_df['Element Name'].unique())}")
print(f"unique values of Element Name: {skills_df['Element Name'].unique()}")

print(f"unique count of O*NET-SOC Code: {len(skills_df['O*NET-SOC Code'].unique())}")
print(f"unique count of SOC code without .specification: {len(skills_df['O*NET-SOC Code'].unique())}")
# Out:
# unique count of Element Name: 35
# unique values of Element Name: ['Reading Comprehension' 'Active Listening' 'Writing' 'Speaking'
#  'Mathematics' 'Science' 'Critical Thinking' 'Active Learning'
#  'Learning Strategies' 'Monitoring' 'Social Perceptiveness' 'Coordination'
#  'Persuasion' 'Negotiation' 'Instructing' 'Service Orientation'
#  'Complex Problem Solving' 'Operations Analysis' 'Technology Design'
#  'Equipment Selection' 'Installation' 'Programming'
#  'Operations Monitoring' 'Operation and Control' 'Equipment Maintenance'
#  'Troubleshooting' 'Repairing' 'Quality Control Analysis'
#  'Judgment and Decision Making' 'Systems Analysis' 'Systems Evaluation'
#  'Time Management' 'Management of Financial Resources'
#  'Management of Material Resources' 'Management of Personnel Resources']
# unique count of O*NET-SOC Code: 879
# unique count of SOC code without .specification: 879

# %%
# Update SOC_Code column based on the condition
skills_df['SOC_Code'] = skills_df['O*NET-SOC Code'].apply(lambda x: x.split('.')[0] if '.' in x else x)

# %%
# skills_df.to_csv('Skills.csv', index=False)

# %% [markdown]
# # skills_importance.csv

# %%
skills_importance_df = skills_df[skills_df['Scale Name'] == 'Importance']

# %%
skills_importance_df  = skills_importance_df.pivot(
    index=['O*NET-SOC Code', 'Title'],
    columns='Element Name',
    values='Data Value'
).reset_index()

# %%
skills_importance_df['normalized_major_code'] = skills_importance_df['O*NET-SOC Code'].str.replace('-', '').str[:2]
skills_importance_df['normalized_minor_code'] = skills_importance_df['O*NET-SOC Code'].str.replace('-', '').str[:3]

# %%
skills_importance_df
# Out:
# Element Name O*NET-SOC Code                                             Title  \
# 0                11-1011.00                                  Chief Executives
# 1                11-1011.03                     Chief Sustainability Officers
# 2                11-1021.00                   General and Operations Managers
# 3                11-2011.00               Advertising and Promotions Managers
# 4                11-2021.00                                Marketing Managers
# ..                      ...                                               ...
# 874              53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 875              53-7072.00           Pump Operators, Except Wellhead Pumpers
# 876              53-7073.00                                  Wellhead Pumpers
# 877              53-7081.00         Refuse and Recyclable Material Collectors
# 878              53-7121.00                 Tank Car, Truck, and Ship Loaders
#
# Element Name  Active Learning  Active Listening  Complex Problem Solving  \
# 0                        3.75              4.00                     4.38
# 1                        3.75              4.00                     4.00
# 2                        3.62              4.00                     3.62
# 3                        3.25              4.12                     3.50
# 4                        3.88              3.88                     3.62
# ..                        ...               ...                      ...
# 874                      2.88              3.12                     3.00
# 875                      2.88              3.12                     2.88
# 876                      2.38              2.88                     3.00
# 877                      2.25              2.88                     2.38
# 878                      2.75              3.00                     3.00
#
# Element Name  Coordination  Critical Thinking  Equipment Maintenance  \
# 0                     4.25               4.38                   1.00
# 1                     3.75               4.12                   1.00
# 2                     3.88               3.88                   1.00
# 3                     3.50               4.00                   1.00
# 4                     3.50               3.88                   1.00
# ..                     ...                ...                    ...
# 874                   3.00               3.62                   3.12
# 875                   2.88               3.12                   2.88
# 876                   2.25               3.12                   3.12
# 877                   2.62               2.75                   2.75
# 878                   2.88               3.00                   2.62
#
# Element Name  Equipment Selection  Installation  Instructing  \
# 0                            1.12          1.00         3.38
# 1                            1.12          1.00         3.25
# 2                            1.00          1.00         3.00
# 3                            1.12          1.00         2.88
# 4                            1.00          1.00         3.00
# ..                            ...           ...          ...
# 874                          2.12          1.00         2.50
# 875                          2.25          1.12         2.88
# 876                          2.25          1.25         2.12
# 877                          1.75          1.00         1.88
# 878                          2.38          1.00         2.50
#
# Element Name  Judgment and Decision Making  Learning Strategies  \
# 0                                     4.75                 3.12
# 1                                     3.88                 3.38
# 2                                     3.62                 3.00
# 3                                     3.75                 3.00
# 4                                     3.75                 3.12
# ..                                     ...                  ...
# 874                                   3.00                 2.25
# 875                                   3.00                 2.12
# 876                                   3.12                 1.88
# 877                                   2.38                 1.38
# 878                                   2.88                 2.50
#
# Element Name  Management of Financial Resources  \
# 0                                          4.25
# 1                                          2.88
# 2                                          3.00
# 3                                          2.75
# 4                                          2.88
# ..                                          ...
# 874                                        1.62
# 875                                        2.00
# 876                                        1.38
# 877                                        1.00
# 878                                        2.00
#
# Element Name  Management of Material Resources  \
# 0                                         4.00
# 1                                         2.25
# 2                                         3.12
# 3                                         2.62
# 4                                         2.62
# ..                                         ...
# 874                                       2.00
# 875                                       2.25
# 876                                       1.75
# 877                                       1.00
# 878                                       2.00
#
# Element Name  Management of Personnel Resources  Mathematics  Monitoring  \
# 0                                          4.25         3.25        4.00
# 1                                          3.12         2.88        3.75
# 2                                          3.75         2.62        4.00
# 3                                          3.12         3.00        3.25
# 4                                          3.38         2.75        3.75
# ..                                          ...          ...         ...
# 874                                        2.25         2.25        3.12
# 875                                        2.62         2.38        3.50
# 876                                        2.12         2.25        3.12
# 877                                        2.00         1.00        2.50
# 878                                        2.88         2.50        3.00
#
# Element Name  Negotiation  Operation and Control  Operations Analysis  \
# 0                    4.12                   1.88                 3.12
# 1                    3.12                   2.00                 2.88
# 2                    3.50                   1.88                 2.50
# 3                    3.12                   1.00                 2.75
# 4                    3.62                   1.00                 3.38
# ..                    ...                    ...                  ...
# 874                  2.25                   3.88                 1.00
# 875                  2.25                   3.50                 1.88
# 876                  2.00                   3.88                 1.38
# 877                  2.00                   3.00                 1.12
# 878                  2.25                   3.75                 1.00
#
# Element Name  Operations Monitoring  Persuasion  Programming  \
# 0                              2.00        4.00         1.75
# 1                              2.00        3.88         1.88
# 2                              2.25        3.62         1.50
# 3                              1.62        3.38         1.75
# 4                              1.75        3.75         1.88
# ..                              ...         ...          ...
# 874                            4.00        2.25         1.38
# 875                            3.88        2.38         1.75
# 876                            4.00        2.00         1.25
# 877                            3.00        2.00         1.00
# 878                            3.75        2.00         1.38
#
# Element Name  Quality Control Analysis  Reading Comprehension  Repairing  \
# 0                                 1.88                   4.12       1.00
# 1                                 1.88                   4.00       1.00
# 2                                 2.38                   4.00       1.00
# 3                                 1.62                   3.75       1.00
# 4                                 1.88                   3.88       1.00
# ..                                 ...                    ...        ...
# 874                               3.00                   3.12       3.00
# 875                               2.88                   3.12       2.75
# 876                               2.38                   2.75       3.12
# 877                               2.25                   2.62       2.50
# 878                               2.88                   3.25       2.50
#
# Element Name  Science  Service Orientation  Social Perceptiveness  Speaking  \
# 0                1.62                 3.12                   4.12      4.25
# 1                2.12                 3.25                   3.88      4.00
# 2                1.50                 3.25                   3.75      4.00
# 3                1.62                 3.12                   4.00      4.00
# 4                1.75                 3.12                   3.88      3.88
# ..                ...                  ...                    ...       ...
# 874              1.88                 2.25                   2.75      3.00
# 875              2.00                 2.38                   2.75      3.12
# 876              1.12                 1.88                   2.50      3.00
# 877              1.00                 2.38                   2.50      2.88
# 878              1.50                 2.25                   2.62      3.00
#
# Element Name  Systems Analysis  Systems Evaluation  Technology Design  \
# 0                         4.12                4.25               1.75
# 1                         3.88                3.88               1.88
# 2                         3.12                3.12               1.50
# 3                         3.12                3.12               1.75
# 4                         3.25                3.50               1.75
# ..                         ...                 ...                ...
# 874                       2.62                2.00               1.88
# 875                       2.38                2.12               1.88
# 876                       2.00                2.00               1.50
# 877                       1.38                1.38               1.00
# 878                       2.50                2.12               1.75
#
# Element Name  Time Management  Troubleshooting  Writing normalized_major_code  \
# 0                        4.00             1.50     4.12                    11
# 1                        3.38             1.00     4.12                    11
# 2                        3.62             1.75     3.50                    11
# 3                        3.50             1.00     3.75                    11
# 4                        3.50             1.00     3.25                    11
# ..                        ...              ...      ...                   ...
# 874                      3.00             3.12     3.00                    53
# 875                      3.00             3.00     2.88                    53
# 876                      2.75             3.12     2.62                    53
# 877                      2.50             2.50     2.50                    53
# 878                      3.12             2.62     3.00                    53
#
# Element Name normalized_minor_code
# 0                              111
# 1                              111
# 2                              111
# 3                              112
# 4                              112
# ..                             ...
# 874                            537
# 875                            537
# 876                            537
# 877                            537
# 878                            537
#
# [879 rows x 39 columns]

# %%
skills_importance_df.sort_values(by='Operations Analysis', ascending=False)[:30][['O*NET-SOC Code', 'Title', 'Operations Analysis']]
# Out:
# Element Name O*NET-SOC Code                                     Title  \
# 123              17-1011.00    Architects, Except Landscape and Naval
# 128              17-2011.00                       Aerospace Engineers
# 152              17-2161.00                         Nuclear Engineers
# 326              27-1027.00                 Set and Exhibit Designers
# 130              17-2031.00     Bioengineers and Biomedical Engineers
# 117              15-2031.00              Operations Research Analysts
# 150              17-2141.02                      Automotive Engineers
# 113              15-1299.08     Computer Systems Engineers/Architects
# 131              17-2041.00                        Chemical Engineers
# 34               11-9111.00      Medical and Health Services Managers
# 124              17-1012.00                      Landscape Architects
# 108              15-1254.00                            Web Developers
# 132              17-2051.00                           Civil Engineers
# 141              17-2111.02  Fire-Prevention and Protection Engineers
# 148              17-2141.00                      Mechanical Engineers
# 209              19-3032.00   Industrial-Organizational Psychologists
# 154              17-2199.03   Energy Engineers, Except Wind and Solar
# 135              17-2061.00               Computer Hardware Engineers
# 316              27-1011.00                             Art Directors
# 133              17-2051.01                  Transportation Engineers
# 4                11-2021.00                        Marketing Managers
# 69               13-1081.01                       Logistics Engineers
# 35               11-9121.00                 Natural Sciences Managers
# 393              29-1223.00                             Psychiatrists
# 160              17-2199.10                     Wind Energy Engineers
# 159              17-2199.09                     Nanosystems Engineers
# 158              17-2199.08                        Robotics Engineers
# 145              17-2112.03                   Manufacturing Engineers
# 157              17-2199.07                       Photonics Engineers
# 321              27-1022.00                         Fashion Designers
#
# Element Name  Operations Analysis
# 123                          4.00
# 128                          3.88
# 152                          3.75
# 326                          3.75
# 130                          3.75
# 117                          3.75
# 150                          3.75
# 113                          3.75
# 131                          3.62
# 34                           3.62
# 124                          3.62
# 108                          3.62
# 132                          3.62
# 141                          3.62
# 148                          3.50
# 209                          3.50
# 154                          3.38
# 135                          3.38
# 316                          3.38
# 133                          3.38
# 4                            3.38
# 69                           3.38
# 35                           3.25
# 393                          3.25
# 160                          3.25
# 159                          3.25
# 158                          3.25
# 145                          3.25
# 157                          3.25
# 321                          3.25

# %%
# skills_importance_df.to_csv('../data/skills/skills_importance.csv', index=False)

# %% [markdown]
# # skill_based_risk

# %%
# Define your skill_categories mapping
skill_categories = {
    'basic_skills': [
        'Reading Comprehension', 'Active Listening', 'Writing', 'Speaking',
    ],
    'cognitive_skills': [
        'Critical Thinking', 'Active Learning', 'Learning Strategies',
        'Monitoring', 'Complex Problem Solving', 'Judgment and Decision Making', 'Operations Analysis'
    ],
    'social_skills': [
        'Social Perceptiveness', 'Coordination', 'Persuasion',
        'Negotiation', 'Instructing', 'Service Orientation'
    ],
    'operations_skills': [
        'Operation and Control', 'Operations Monitoring', 'Quality Control Analysis', 'Troubleshooting'
    ],
    'maintenance_skills': [
        'Equipment Selection', 'Installation', 'Equipment Maintenance', 'Repairing'
    ],
    'technical_skills': [
        'Technology Design', 'Programming', 'Mathematics', 'Science'
    ],
    'management_skills': [
        'Systems Analysis', 'Systems Evaluation', 'Time Management',
        'Management of Financial Resources', 'Management of Material Resources',
        'Management of Personnel Resources'
    ]
}

# Prepare a dict for the new DataFrame
new_data = {
    'O*NET-SOC Code': skills_importance_df['O*NET-SOC Code'],
    'Title': skills_importance_df['Title'],
}

# For each category, compute the mean of the mapped columns and add as a new column
for cat, skills in skill_categories.items():
    present_skills = [s for s in skills if s in skills_importance_df.columns]
    new_data[cat] = skills_importance_df[present_skills].mean(axis=1)

# Create the new DataFrame
skills_combined_df = pd.DataFrame(new_data)

# Display the first few rows to check
display(skills_combined_df.head())
# Out:
#   O*NET-SOC Code                                Title  basic_skills  \
# 0     11-1011.00                     Chief Executives        4.1225
# 1     11-1011.03        Chief Sustainability Officers        4.0300
# 2     11-1021.00      General and Operations Managers        3.8750
# 3     11-2011.00  Advertising and Promotions Managers        3.9050
# 4     11-2021.00                   Marketing Managers        3.7225
#
#    cognitive_skills  social_skills  operations_skills  maintenance_skills  \
# 0          3.928571       3.831667             1.8150                1.03
# 1          3.680000       3.521667             1.7200                1.03
# 2          3.462857       3.500000             2.0650                1.00
# 3          3.357143       3.333333             1.3100                1.03
# 4          3.625714       3.478333             1.4075                1.00
#
#    technical_skills  management_skills
# 0            2.0925           4.145000
# 1            2.1900           3.231667
# 2            1.7800           3.288333
# 3            2.0300           3.038333
# 4            2.0325           3.188333

# %%
skills_combined_df.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'basic_skills', 'cognitive_skills',
#        'social_skills', 'operations_skills', 'maintenance_skills',
#        'technical_skills', 'management_skills'],
#       dtype='object')

# %%
state = 'California' # The columns we are interested in are same across all the states
national_detailed_file_path = '../generation/national_summary_detailed.csv'
national_detailed_df = pd.read_csv(national_detailed_file_path)
national_detailed_df = national_detailed_df[national_detailed_df['AREA_TITLE'] == state]

# %%
national_detailed_df.head()
# Out:
#       AREA  AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 2682     6  California          2         CA      0  Cross-industry
# 2683     6  California          2         CA      0  Cross-industry
# 2684     6  California          2         CA      0  Cross-industry
# 2685     6  California          2         CA      0  Cross-industry
# 2686     6  California          2         CA      0  Cross-industry
#
#              I_GROUP  OWN_CODE OCC_CODE                            OCC_TITLE  \
# 2682  cross-industry      1235  11-1011                     Chief Executives
# 2683  cross-industry      1235  11-1021      General and Operations Managers
# 2684  cross-industry      1235  11-1031                          Legislators
# 2685  cross-industry      1235  11-2011  Advertising and Promotions Managers
# 2686  cross-industry      1235  11-2021                   Marketing Managers
#
#        O_GROUP   TOT_EMP EMP_PRSE JOBS_1000 LOC_QUOTIENT  PCT_TOTAL  PCT_RPT  \
# 2682  detailed   38920.0      2.4     2.169         1.56        NaN      NaN
# 2683  detailed  273630.0      0.9    15.248         0.66        NaN      NaN
# 2684  detailed    2120.0      5.2     0.118         0.55        NaN      NaN
# 2685  detailed    2880.0      7.2     0.160         1.18        NaN      NaN
# 2686  detailed   59830.0      2.8     3.334         1.37        NaN      NaN
#
#       H_MEAN    A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN H_PCT75 H_PCT90  \
# 2682  135.11  281030.0       1.4   42.01   70.21   111.10       #       #
# 2683   74.60  155170.0       4.2   29.57   39.52    58.72   86.00       #
# 2684       *   86890.0       2.9       *       *        *       *       *
# 2685   84.18  175080.0       6.0   36.99   50.12    67.48   97.44       #
# 2686   92.66  192730.0       1.0   45.87   62.45    83.89  109.89       #
#
#      A_PCT10  A_PCT25  A_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY  \
# 2682  87,390  146,030  231080.0        #        #    NaN    NaN
# 2683  61,500   82,210  122140.0  178,870        #    NaN    NaN
# 2684  34,810   38,940   62380.0  104,450  136,310   True    NaN
# 2685  76,950  104,240  140360.0  202,670        #    NaN    NaN
# 2686  95,400  129,890  174480.0  228,560        #    NaN    NaN
#
#       SOC_Code_Cleaned  tech_intensity_score  automation_susceptibility  \
# 2682            111011             12.305882                  37.703481
# 2683            111021             14.610314                  43.238114
# 2684            111031             10.412132                  32.905331
# 2685            112011             13.092828                  40.677276
# 2686            112021             18.600310                  55.711300
#
#      automation_risk_category  major_group  estimated_zapier_apps_major  \
# 2682                      Low           11                          0.0
# 2683                 Moderate           11                          0.0
# 2684                      Low           11                          0.0
# 2685                 Moderate           11                          0.0
# 2686                 Moderate           11                          0.0
#
#       major_group_emp_total  emp_proportion  estimated_zapier_apps  \
# 2682              1308810.0        0.029737                    0.0
# 2683              1308810.0        0.209068                    0.0
# 2684              1308810.0        0.001620                    0.0
# 2685              1308810.0        0.002200                    0.0
# 2686              1308810.0        0.045713                    0.0
#
#       zapier_apps_per_worker  zapier_apps_normalized  \
# 2682                     0.0                       0
# 2683                     0.0                       0
# 2684                     0.0                       0
# 2685                     0.0                       0
# 2686                     0.0                       0
#
#       automation_susceptibility_norm  enhanced_automation_risk  \
# 2682                        0.377035                 28.277611
# 2683                        0.432381                 32.428586
# 2684                        0.329053                 24.678998
# 2685                        0.406773                 30.507957
# 2686                        0.557113                 41.783475
#
#      enhanced_risk_category  economic_value  is_potentially_at_risk  \
# 2682                    Low    1.093769e+10                   False
# 2683                    Low    4.245917e+10                   False
# 2684                    Low    1.842068e+08                   False
# 2685                    Low    5.042304e+08                   False
# 2686               Moderate    1.153104e+10                    True
#
#       is_currently_at_risk  potential_index  econ_potential_index  \
# 2682                 False              0.0              0.089501
# 2683                 False              0.0              0.398438
# 2684                 False              0.0              0.001316
# 2685                 False              0.0              0.004451
# 2686                 False            100.0              0.139423
#
#       minor_group  minor_group_name       state
# 2682          111               111  California
# 2683          111               111  California
# 2684          111               111  California
# 2685          112               112  California
# 2686          112               112  California

# %%
def get_automation_sustainability_score_component(onet_soc_code):
    global national_detailed_df
    if '.' in onet_soc_code:
        occ_code = onet_soc_code.split('.')[0]
    else:
        occ_code = onet_soc_code

    occ_df = national_detailed_df[national_detailed_df['OCC_CODE'] == occ_code]
    if occ_df.empty:
        print(f"No data found for {occ_code} in national_detailed_df")
        return None

    score = occ_df['automation_susceptibility_norm'].iloc[0]
    return float(score)

# %%
def add_automation_sustainability_score_component(df):
    global national_detailed_df
    
    top_10_perc_thresh = df["technical_skills"].quantile(0.9)
    df["automation_risk"] = df["intermediate_automation_risk"]
    ctr = 0
    for index, row in df.iterrows():
        technical_skills = row["technical_skills"]
        if technical_skills >= top_10_perc_thresh:
            automation_sustainability_norm = get_automation_sustainability_score_component(row["O*NET-SOC Code"])
            if automation_sustainability_norm is not None:
                ctr += 1
                df.at[index, "automation_risk"] = 0.2 * df.at[index, "intermediate_automation_risk"] + 0.8 * automation_sustainability_norm
    
    print(f"Updated {ctr} jobs with automation_susceptibility_norm score")
    df["automation_risk_score"] = (
        100 / (1 + np.exp(-4 * ((df["automation_risk"]) - 0.40)))
    ).round(1)
    return df

# %%
# import re
# ------------------------------------------------------------
# 1.  sector‑growth keywords for the WEF “discount” step
# ------------------------------------------------------------
# GROWTH_SECTOR_PATTERNS = re.compile(
#     r"(nurs|therap|counsel|teacher|educat|"      # care & education
#     r"ai\b|ml\b|machine learning|data|cyber|"    # digital / AI / security
#     r"engineer|developer|analyst|"               # generic digital titles
#     r"renewable|solar|wind|green|sustain|"       # green transition
#     r"project manager|operations manager)",      # leadership / project
#     flags=re.I
# )

# ------------------------------------------------------------
# 2.  helper to normalize each 1‑to‑5 skill bucket to 0‑1
# ------------------------------------------------------------
def _norm(series: pd.Series) -> pd.Series:
    return (series - 1.0) / 4.0

# ------------------------------------------------------------
# 3.  main scorer
# ------------------------------------------------------------
def add_intermediate_automation_risk(df: pd.DataFrame) -> pd.DataFrame:
    """Append a 0‑100 'automation_risk_score' column to the skills dataframe.

    Expected numeric columns (1‑5 scale):
      basic_skills, cognitive_skills, social_skills,
      operations_skills, maintenance_skills,
      technical_skills, management_skills
    """
    # 1. normalise buckets
    basic_skills  = _norm(df["basic_skills"])
    cognitive_skills  = _norm(df["cognitive_skills"])
    social_skills  = _norm(df["social_skills"])
    operations_skills  = _norm(df["operations_skills"])
    maintenance_skills  = _norm(df["maintenance_skills"])
    technical_skills  = _norm(df["technical_skills"])
    management_skills  = _norm(df["management_skills"])

    # 2. composite indices
    field_intensity = 0.3 * operations_skills + 0.7 * maintenance_skills
    # human_capital     = (
    #     0.60 * social_skills + 0.40 * management_skills # + 0.20 * cognitive_skills + 0.10 * basic_skills
    # )   # ↑ social/management weight, ↓ basic  #v1 - works for food grader

    human_capital     = (
        np.maximum(social_skills, management_skills) # any such skill heavily required would be a good indicator of human capital
    )   # ↑ social/management weight, ↓ basic
    
    tech_shield       = 0.30 * technical_skills + 0.10 * cognitive_skills 
    # tech shield is the sum of technical and cognitive skills - helps in longer term job creation but not in short term

    tech_composition = (technical_skills) / (technical_skills + management_skills + social_skills + maintenance_skills)

    # 3. raw risk (0‑1) with updated weights
    # Long-term
    # raw = (
    #     0.55 * routine_intensity
    #     + 0.30 * (1 - human_capital)
    #     + 0.15 * (1 - tech_shield)
    # )

    # Modified
    # Short-term
    raw = (
        0.5 * (tech_composition)  # The more technical the job, the higher the risk
        + 0.3 * (1 - field_intensity)
        + 0.2 * (1 - human_capital)
        # + 0.15 * (1 - tech_shield)
    )

    # 4. WEF growth‑sector discount (‑30 %) – stricter threshold
    # mask_growth = df["Title"].str.contains(GROWTH_SECTOR_PATTERNS, na=False) & (
    #     (social_skills >= 0.60) | (technical_skills >= 0.60)   # need ≥3.4 in raw 1‑5 scale
    # )

    # raw = raw.mask(mask_growth, raw * 0.70)

    # 5. scale to 0‑100
    df = df.copy()
    df["intermediate_automation_risk"] = (raw).round(2)
    # df["automation_risk_score"] = (
    #     100 / (1 + np.exp(-4 * (raw - 0.40)))
    # ).round(1)

    return df

# %%
def find_most_similar_job_from_skills_df(onet_soc_code, skills_df) -> str:
    """
        return the most similar job (O*NET-SOC Code) from skills_df to the given onet_soc_code (O*NET-SOC Code)
    """
    # Get all unique O*NET-SOC codes from the skills dataframe
    available_codes = skills_df['O*NET-SOC Code'].unique()
    
    # If the exact code exists, return it
    if onet_soc_code in available_codes:
        return onet_soc_code
    
    max_common_length = 0
    candidates = []
    
    # First pass: find all codes with the maximum common prefix length
    for code in available_codes:
        # Calculate common prefix length
        common_length = 0
        min_length = min(len(onet_soc_code), len(code))
        
        for i in range(min_length):
            if onet_soc_code[i] == code[i]:
                common_length += 1
            else:
                break
        
        # Update candidates if this has a longer common prefix
        if common_length > max_common_length:
            max_common_length = common_length
            candidates = [code]
        elif common_length == max_common_length:
            candidates.append(code)
    
    # If only one candidate, return it
    if len(candidates) == 1:
        return candidates[0]
    
    # Second pass: among candidates with same prefix length, find closest differing character
    best_match = None
    min_diff = float('inf')
    
    for code in candidates:
        if max_common_length < len(onet_soc_code) and max_common_length < len(code):
            # Compare the differing characters
            char1 = onet_soc_code[max_common_length]
            char2 = code[max_common_length]
            
            # If both are digits, compare numerically
            if char1.isdigit() and char2.isdigit():
                diff = abs(int(char1) - int(char2))
            else:
                # Fallback to ASCII difference for non-numeric characters
                diff = abs(ord(char1) - ord(char2))
            
            if diff < min_diff:
                min_diff = diff
                best_match = code
        else:
            # If one string is shorter, prefer the shorter one (more general)
            if best_match is None:
                best_match = code
    
    return best_match if best_match is not None else candidates[0]
    

def add_missing_jobs_from_national_detailed_df(national_detailed_df, skills_combined_df) -> pd.DataFrame:
    job_codes_indexed = set(skills_combined_df["O*NET-SOC Code"].values)

    national_detailed_df = national_detailed_df.drop_duplicates(subset="OCC_CODE", keep="first")[["OCC_CODE", "OCC_TITLE"]]
    national_detailed_df["O*NET-SOC Code"] = national_detailed_df["OCC_CODE"].apply(lambda x: f"{x}.00")
    
    # Add missing_job column if it doesn't exist
    if 'missing_job' not in skills_combined_df.columns:
        skills_combined_df['missing_job'] = False

    missing_jobs_onet_soc_codes = []
    rows_to_add = []
    
    for index, row in national_detailed_df.iterrows():
        code = row["O*NET-SOC Code"]
        title = row["OCC_TITLE"]

        if code in job_codes_indexed:
            continue

        # Find the most similar job
        replaced_code = find_most_similar_job_from_skills_df(code, skills_combined_df)
        if replaced_code is None:
            print(f"No similar job found for: {code} - {title}")
            continue
            
        # Get the closest job row
        closest_job_rows = skills_combined_df[skills_combined_df["O*NET-SOC Code"] == replaced_code]
        if closest_job_rows.empty:
            print(f"Replaced code {replaced_code} not found in dataframe")
            continue
            
        closest_job_row = closest_job_rows.iloc[0].copy()
        
        # Update the row with new information
        closest_job_row["O*NET-SOC Code"] = code
        closest_job_row["Title"] = title
        closest_job_row['missing_job'] = True
        
        rows_to_add.append(closest_job_row)

        print(f"Missing job: {code} - {title} --> replacing with most similar job {replaced_code} - {closest_job_rows.iloc[0]['Title']}")
        missing_jobs_onet_soc_codes.append(code)
    
    # Add all new rows at once using pd.concat (more efficient than append)
    if rows_to_add:
        new_rows_df = pd.DataFrame(rows_to_add)
        skills_combined_df = pd.concat([skills_combined_df, new_rows_df], ignore_index=True)
    
    print(f"Mapped {len(missing_jobs_onet_soc_codes)} missing jobs from skills.csv")

    return skills_combined_df

# %%
def add_adoption_rate_to_skills_df(skills_df):
    """
    Add adoption rate to skills_df
    """
    tech_intensity_df = pd.read_csv(TECH_INTENSITY_PATH)
    tech_intensity_df = tech_intensity_df.rename(columns={'hot_tech_ratio': 'adoption_rate'})  # hot tech ratio is a proxy
    
    tech_intensity_df = tech_intensity_df[['O*NET-SOC Code', 'adoption_rate']]
    skills_df = skills_df.merge(tech_intensity_df, on=['O*NET-SOC Code'], how='left')
    
    skills_df['adoption_rate'] = skills_df['adoption_rate'].fillna(skills_df['adoption_rate'].median())
    return skills_df

# %%
skills_combined_df[skills_combined_df["O*NET-SOC Code"] == "19-1099.00"]
# Out:
# Empty DataFrame
# Columns: [O*NET-SOC Code, Title, basic_skills, cognitive_skills, social_skills, operations_skills, maintenance_skills, technical_skills, management_skills]
# Index: []

# %%
# ------------------------------------------------------------
# 4.  usage
# ------------------------------------------------------------
skills_combined_df = add_intermediate_automation_risk(skills_combined_df)

# %%
skills_combined_df = add_automation_sustainability_score_component(skills_combined_df)
# Out:
# No data found for 29-2036 in national_detailed_df
# Updated 87 jobs with automation_susceptibility_norm score

# %%
skills_combined_df = add_missing_jobs_from_national_detailed_df(national_detailed_df, skills_combined_df)
# Out:
# Missing job: 11-1031.00 - Legislators --> replacing with most similar job 11-1021.00 - General and Operations Managers
# Missing job: 11-2032.00 - Public Relations Managers --> replacing with most similar job 11-2021.00 - Marketing Managers
# Missing job: 11-2033.00 - Fundraising Managers --> replacing with most similar job 11-2021.00 - Marketing Managers
# Missing job: 11-9039.00 - Education Administrators, All Other --> replacing with most similar job 11-9033.00 - Education Administrators, Postsecondary
# Missing job: 11-9072.00 - Entertainment and Recreation Managers, Except Gambling --> replacing with most similar job 11-9071.00 - Gambling Managers
# Missing job: 11-9179.00 - Personal Service Managers, All Other --> replacing with most similar job 11-9179.01 - Fitness and Wellness Coordinators
# Missing job: 11-9199.00 - Managers, All Other --> replacing with most similar job 11-9199.01 - Regulatory Affairs Managers
# Missing job: 13-1020.00 - Buyers and Purchasing Agents --> replacing with most similar job 13-1021.00 - Buyers and Purchasing Agents, Farm Products
# Missing job: 13-1082.00 - Project Management Specialists --> replacing with most similar job 13-1081.00 - Logisticians
# Missing job: 13-1199.00 - Business Operations Specialists, All Other --> replacing with most similar job 13-1199.04 - Business Continuity Planners
# Missing job: 13-2020.00 - Property Appraisers and Assessors --> replacing with most similar job 13-2023.00 - Appraisers and Assessors of Real Estate
# Missing job: 13-2051.00 - Financial and Investment Analysts --> replacing with most similar job 13-2052.00 - Personal Financial Advisors
# Missing job: 13-2054.00 - Financial Risk Specialists --> replacing with most similar job 13-2053.00 - Insurance Underwriters
# Missing job: 13-2099.00 - Financial Specialists, All Other --> replacing with most similar job 13-2099.01 - Financial Quantitative Analysts
# Missing job: 15-1252.00 - Software Developers --> replacing with most similar job 15-1251.00 - Computer Programmers
# Missing job: 15-1255.00 - Web and Digital Interface Designers --> replacing with most similar job 15-1255.01 - Video Game Designers
# Missing job: 15-1299.00 - Computer Occupations, All Other --> replacing with most similar job 15-1299.01 - Web Administrators
# Missing job: 15-2051.00 - Data Scientists --> replacing with most similar job 15-2051.01 - Business Intelligence Analysts
# Missing job: 15-2099.00 - Mathematical Science Occupations, All Other --> replacing with most similar job 15-2099.01 - Bioinformatics Technicians
# Missing job: 17-2199.00 - Engineers, All Other --> replacing with most similar job 17-2199.03 - Energy Engineers, Except Wind and Solar
# Missing job: 17-3019.00 - Drafters, All Other --> replacing with most similar job 17-3013.00 - Mechanical Drafters
# Missing job: 17-3028.00 - Calibration Technologists and Technicians --> replacing with most similar job 17-3027.00 - Mechanical Engineering Technologists and Technicians
# Missing job: 17-3029.00 - Engineering Technologists and Technicians, Except Drafters, All Other --> replacing with most similar job 17-3029.01 - Non-Destructive Testing Specialists
# Missing job: 19-1029.00 - Biological Scientists, All Other --> replacing with most similar job 19-1029.01 - Bioinformatics Scientists
# Missing job: 19-1099.00 - Life Scientists, All Other --> replacing with most similar job 19-1041.00 - Epidemiologists
# Missing job: 19-2099.00 - Physical Scientists, All Other --> replacing with most similar job 19-2099.01 - Remote Sensing Scientists and Technologists
# Missing job: 19-3039.00 - Psychologists, All Other --> replacing with most similar job 19-3039.02 - Neuropsychologists
# Missing job: 19-3099.00 - Social Scientists and Related Workers, All Other --> replacing with most similar job 19-3099.01 - Transportation Planners
# Missing job: 19-4044.00 - Hydrologic Technicians --> replacing with most similar job 19-4043.00 - Geological Technicians, Except Hydrologic Technicians
# Missing job: 19-4099.00 - Life, Physical, and Social Science Technicians, All Other --> replacing with most similar job 19-4099.01 - Quality Control Analysts
# Missing job: 21-1018.00 - Substance Abuse, Behavioral Disorder, and Mental Health Counselors --> replacing with most similar job 21-1015.00 - Rehabilitation Counselors
# Missing job: 21-1019.00 - Counselors, All Other --> replacing with most similar job 21-1015.00 - Rehabilitation Counselors
# Missing job: 21-1029.00 - Social Workers, All Other --> replacing with most similar job 21-1023.00 - Mental Health and Substance Abuse Social Workers
# Missing job: 21-1099.00 - Community and Social Service Specialists, All Other --> replacing with most similar job 21-1094.00 - Community Health Workers
# Missing job: 21-2099.00 - Religious Workers, All Other --> replacing with most similar job 21-2021.00 - Directors, Religious Activities and Education
# Missing job: 23-2099.00 - Legal Support Workers, All Other --> replacing with most similar job 23-2093.00 - Title Examiners, Abstractors, and Searchers
# Missing job: 25-1069.00 - Social Sciences Teachers, Postsecondary, All Other --> replacing with most similar job 25-1067.00 - Sociology Teachers, Postsecondary
# Missing job: 25-2052.00 - Special Education Teachers, Kindergarten and Elementary School --> replacing with most similar job 25-2051.00 - Special Education Teachers, Preschool
# Missing job: 25-2059.00 - Special Education Teachers, All Other --> replacing with most similar job 25-2059.01 - Adapted Physical Education Specialists
# Missing job: 25-3031.00 - Substitute Teachers, Short-Term --> replacing with most similar job 25-3021.00 - Self-Enrichment Teachers
# Missing job: 25-3099.00 - Teachers and Instructors, All Other --> replacing with most similar job 25-3041.00 - Tutors
# Missing job: 25-9045.00 - Teaching Assistants, Except Postsecondary --> replacing with most similar job 25-9044.00 - Teaching Assistants, Postsecondary
# Missing job: 25-9099.00 - Educational Instruction and Library Workers, All Other --> replacing with most similar job 25-9042.00 - Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education
# Missing job: 27-1019.00 - Artists and Related Workers, All Other --> replacing with most similar job 27-1014.00 - Special Effects Artists and Animators
# Missing job: 27-1029.00 - Designers, All Other --> replacing with most similar job 27-1027.00 - Set and Exhibit Designers
# Missing job: 27-2091.00 - Disc Jockeys, Except Radio --> replacing with most similar job 27-2041.00 - Music Directors and Composers
# Missing job: 27-2099.00 - Entertainers and Performers, Sports and Related Workers, All Other --> replacing with most similar job 27-2041.00 - Music Directors and Composers
# Missing job: 27-3099.00 - Media and Communication Workers, All Other --> replacing with most similar job 27-3092.00 - Court Reporters and Simultaneous Captioners
# Missing job: 27-4015.00 - Lighting Technicians --> replacing with most similar job 27-4014.00 - Sound Engineering Technicians
# Missing job: 27-4099.00 - Media and Communication Equipment Workers, All Other --> replacing with most similar job 27-4031.00 - Camera Operators, Television, Video, and Film
# Missing job: 29-1029.00 - Dentists, All Other Specialists --> replacing with most similar job 29-1024.00 - Prosthodontists
# Missing job: 29-1129.00 - Therapists, All Other --> replacing with most similar job 29-1129.01 - Art Therapists
# Missing job: 29-1212.00 - Cardiologists --> replacing with most similar job 29-1211.00 - Anesthesiologists
# Missing job: 29-1214.00 - Emergency Medicine Physicians --> replacing with most similar job 29-1213.00 - Dermatologists
# Missing job: 29-1229.00 - Physicians, All Other --> replacing with most similar job 29-1229.01 - Allergists and Immunologists
# Missing job: 29-1242.00 - Orthopedic Surgeons, Except Pediatric --> replacing with most similar job 29-1241.00 - Ophthalmologists, Except Pediatric
# Missing job: 29-1243.00 - Pediatric Surgeons --> replacing with most similar job 29-1241.00 - Ophthalmologists, Except Pediatric
# Missing job: 29-1249.00 - Surgeons, All Other --> replacing with most similar job 29-1241.00 - Ophthalmologists, Except Pediatric
# Missing job: 29-1299.00 - Healthcare Diagnosing or Treating Practitioners, All Other --> replacing with most similar job 29-1299.01 - Naturopathic Physicians
# Missing job: 29-2010.00 - Clinical Laboratory Technologists and Technicians --> replacing with most similar job 29-2011.00 - Medical and Clinical Laboratory Technologists
# Missing job: 29-2042.00 - Emergency Medical Technicians --> replacing with most similar job 29-2031.00 - Cardiovascular Technologists and Technicians
# Missing job: 29-2043.00 - Paramedics --> replacing with most similar job 29-2031.00 - Cardiovascular Technologists and Technicians
# Missing job: 29-2072.00 - Medical Records Specialists --> replacing with most similar job 29-2061.00 - Licensed Practical and Licensed Vocational Nurses
# Missing job: 29-2099.00 - Health Technologists and Technicians, All Other --> replacing with most similar job 29-2099.01 - Neurodiagnostic Technologists
# Missing job: 29-9021.00 - Health Information Technologists and Medical Registrars --> replacing with most similar job 29-9091.00 - Athletic Trainers
# Missing job: 29-9099.00 - Healthcare Practitioners and Technical Workers, All Other --> replacing with most similar job 29-9099.01 - Midwives
# Missing job: 31-1120.00 - Home Health and Personal Care Aides --> replacing with most similar job 31-1121.00 - Home Health Aides
# Missing job: 31-9099.00 - Healthcare Support Workers, All Other --> replacing with most similar job 31-9099.01 - Speech-Language Pathology Assistants
# Missing job: 33-1091.00 - First-Line Supervisors of Security Workers --> replacing with most similar job 33-1021.00 - First-Line Supervisors of Firefighting and Prevention Workers
# Missing job: 33-1099.00 - First-Line Supervisors of Protective Service Workers, All Other --> replacing with most similar job 33-1021.00 - First-Line Supervisors of Firefighting and Prevention Workers
# Missing job: 33-9094.00 - School Bus Monitors --> replacing with most similar job 33-9093.00 - Transportation Security Screeners
# Missing job: 33-9099.00 - Protective Service Workers, All Other --> replacing with most similar job 33-9099.02 - Retail Loss Prevention Specialists
# Missing job: 35-2019.00 - Cooks, All Other --> replacing with most similar job 35-2015.00 - Cooks, Short Order
# Missing job: 35-9099.00 - Food Preparation and Serving Related Workers, All Other --> replacing with most similar job 35-9031.00 - Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# Missing job: 37-2019.00 - Building Cleaning Workers, All Other --> replacing with most similar job 37-2012.00 - Maids and Housekeeping Cleaners
# Missing job: 37-3019.00 - Grounds Maintenance Workers, All Other --> replacing with most similar job 37-3013.00 - Tree Trimmers and Pruners
# Missing job: 39-1014.00 - First-Line Supervisors of Entertainment and Recreation Workers, Except Gambling Services --> replacing with most similar job 39-1013.00 - First-Line Supervisors of Gambling Services Workers
# Missing job: 39-3019.00 - Gambling Service Workers, All Other --> replacing with most similar job 39-3012.00 - Gambling and Sports Book Writers and Runners
# Missing job: 39-3099.00 - Entertainment Attendants and Related Workers, All Other --> replacing with most similar job 39-3093.00 - Locker Room, Coatroom, and Dressing Room Attendants
# Missing job: 39-4012.00 - Crematory Operators --> replacing with most similar job 39-4011.00 - Embalmers
# Missing job: 39-7010.00 - Tour and Travel Guides --> replacing with most similar job 39-7011.00 - Tour Guides and Escorts
# Missing job: 39-9099.00 - Personal Care and Service Workers, All Other --> replacing with most similar job 39-9041.00 - Residential Advisors
# Missing job: 41-3091.00 - Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel --> replacing with most similar job 41-3041.00 - Travel Agents
# Missing job: 41-9099.00 - Sales and Related Workers, All Other --> replacing with most similar job 41-9091.00 - Door-to-Door Sales Workers, News and Street Vendors, and Related Workers
# Missing job: 43-2099.00 - Communications Equipment Operators, All Other --> replacing with most similar job 43-2021.00 - Telephone Operators
# Missing job: 43-3099.00 - Financial Clerks, All Other --> replacing with most similar job 43-3071.00 - Tellers
# Missing job: 43-4199.00 - Information and Record Clerks, All Other --> replacing with most similar job 43-4181.00 - Reservation and Transportation Ticket Agents and Travel Clerks
# Missing job: 43-9199.00 - Office and Administrative Support Workers, All Other --> replacing with most similar job 43-9111.00 - Statistical Assistants
# Missing job: 45-2099.00 - Agricultural Workers, All Other --> replacing with most similar job 45-2093.00 - Farmworkers, Farm, Ranch, and Aquacultural Animals
# Missing job: 45-4029.00 - Logging Workers, All Other --> replacing with most similar job 45-4023.00 - Log Graders and Scalers
# Missing job: 47-3019.00 - Helpers, Construction Trades, All Other --> replacing with most similar job 47-3016.00 - Helpers--Roofers
# Missing job: 47-4090.00 - Miscellaneous Construction and Related Workers --> replacing with most similar job 47-4091.00 - Segmental Pavers
# Missing job: 47-5099.00 - Extraction Workers, All Other --> replacing with most similar job 47-5081.00 - Helpers--Extraction Workers
# Missing job: 49-9069.00 - Precision Instrument and Equipment Repairers, All Other --> replacing with most similar job 49-9064.00 - Watch and Clock Repairers
# Missing job: 49-9099.00 - Installation, Maintenance, and Repair Workers, All Other --> replacing with most similar job 49-9099.01 - Geothermal Technicians
# Missing job: 51-2028.00 - Electrical, Electronic, and Electromechanical Assemblers, Except Coil Winders, Tapers, and Finishers --> replacing with most similar job 51-2023.00 - Electromechanical Equipment Assemblers
# Missing job: 51-2090.00 - Miscellaneous Assemblers and Fabricators --> replacing with most similar job 51-2092.00 - Team Assemblers
# Missing job: 51-3099.00 - Food Processing Workers, All Other --> replacing with most similar job 51-3093.00 - Food Cooking Machine Operators and Tenders
# Missing job: 51-4199.00 - Metal Workers and Plastic Workers, All Other --> replacing with most similar job 51-4194.00 - Tool Grinders, Filers, and Sharpeners
# Missing job: 51-6099.00 - Textile, Apparel, and Furnishings Workers, All Other --> replacing with most similar job 51-6093.00 - Upholsterers
# Missing job: 51-7099.00 - Woodworkers, All Other --> replacing with most similar job 51-7041.00 - Sawing Machine Setters, Operators, and Tenders, Wood
# Missing job: 51-8099.00 - Plant and System Operators, All Other --> replacing with most similar job 51-8099.01 - Biofuels Processing Technicians
# Missing job: 51-9199.00 - Production Workers, All Other --> replacing with most similar job 51-9198.00 - Helpers--Production Workers
# Missing job: 53-1047.00 - First-Line Supervisors of Transportation and Material Moving Workers, Except Aircraft Cargo Handling Supervisors --> replacing with most similar job 53-1043.00 - First-Line Supervisors of Material-Moving Machine and Vehicle Operators
# Missing job: 53-3051.00 - Bus Drivers, School --> replacing with most similar job 53-3052.00 - Bus Drivers, Transit and Intercity
# Missing job: 53-3053.00 - Shuttle Drivers and Chauffeurs --> replacing with most similar job 53-3052.00 - Bus Drivers, Transit and Intercity
# Missing job: 53-3054.00 - Taxi Drivers --> replacing with most similar job 53-3052.00 - Bus Drivers, Transit and Intercity
# Missing job: 53-3099.00 - Motor Vehicle Operators, All Other --> replacing with most similar job 53-3052.00 - Bus Drivers, Transit and Intercity
# Missing job: 53-4099.00 - Rail Transportation Workers, All Other --> replacing with most similar job 53-4041.00 - Subway and Streetcar Operators
# Missing job: 53-6032.00 - Aircraft Service Attendants --> replacing with most similar job 53-6031.00 - Automotive and Watercraft Service Attendants
# Missing job: 53-6099.00 - Transportation Workers, All Other --> replacing with most similar job 53-6061.00 - Passenger Attendants
# Missing job: 53-7199.00 - Material Moving Workers, All Other --> replacing with most similar job 53-7121.00 - Tank Car, Truck, and Ship Loaders
# Mapped 112 missing jobs from skills.csv

# %%
skills_combined_df = add_adoption_rate_to_skills_df(skills_combined_df)

# %%
skills_combined_df.head()
# Out:
#   O*NET-SOC Code                                Title  basic_skills  \
# 0     11-1011.00                     Chief Executives        4.1225
# 1     11-1011.03        Chief Sustainability Officers        4.0300
# 2     11-1021.00      General and Operations Managers        3.8750
# 3     11-2011.00  Advertising and Promotions Managers        3.9050
# 4     11-2021.00                   Marketing Managers        3.7225
#
#    cognitive_skills  social_skills  operations_skills  maintenance_skills  \
# 0          3.928571       3.831667             1.8150                1.03
# 1          3.680000       3.521667             1.7200                1.03
# 2          3.462857       3.500000             2.0650                1.00
# 3          3.357143       3.333333             1.3100                1.03
# 4          3.625714       3.478333             1.4075                1.00
#
#    technical_skills  management_skills  intermediate_automation_risk  \
# 0            2.0925           4.145000                          0.40
# 1            2.1900           3.231667                          0.46
# 2            1.7800           3.288333                          0.42
# 3            2.0300           3.038333                          0.47
# 4            2.0325           3.188333                          0.46
#
#    automation_risk  automation_risk_score  missing_job  adoption_rate
# 0             0.40                   50.0        False       0.346939
# 1             0.46                   56.0        False       0.666667
# 2             0.42                   52.0        False       0.335616
# 3             0.47                   57.0        False       0.397260
# 4             0.46                   56.0        False       0.460526

# %%
skills_combined_df[skills_combined_df['missing_job'] == True]
# Out:
#     O*NET-SOC Code                                              Title  \
# 879     11-1031.00                                        Legislators
# 880     11-2032.00                          Public Relations Managers
# 881     11-2033.00                               Fundraising Managers
# 882     11-9039.00                Education Administrators, All Other
# 883     11-9072.00  Entertainment and Recreation Managers, Except ...
# ..             ...                                                ...
# 986     53-3099.00                 Motor Vehicle Operators, All Other
# 987     53-4099.00             Rail Transportation Workers, All Other
# 988     53-6032.00                        Aircraft Service Attendants
# 989     53-6099.00                  Transportation Workers, All Other
# 990     53-7199.00                 Material Moving Workers, All Other
#
#      basic_skills  cognitive_skills  social_skills  operations_skills  \
# 879        3.8750          3.462857       3.500000             2.0650
# 880        3.7225          3.625714       3.478333             1.4075
# 881        3.7225          3.625714       3.478333             1.4075
# 882        4.0300          3.590000       3.685000             1.3450
# 883        3.6875          3.447143       3.583333             1.9675
# ..            ...               ...            ...                ...
# 986        2.8425          2.427143       2.560000             2.9050
# 987        3.2175          2.820000       2.811667             3.2200
# 988        2.9025          2.535714       2.748333             2.7475
# 989        3.2500          2.427143       3.168333             2.2825
# 990        3.0625          2.590000       2.416667             3.2500
#
#      maintenance_skills  technical_skills  management_skills  \
# 879              1.0000            1.7800           3.288333
# 880              1.0000            2.0325           3.188333
# 881              1.0000            2.0325           3.188333
# 882              1.0000            1.8450           3.375000
# 883              1.0000            1.9975           3.226667
# ..                  ...               ...                ...
# 986              1.4700            1.4375           2.083333
# 987              1.8425            1.3450           2.186667
# 988              2.5950            1.6250           2.206667
# 989              1.0000            1.4700           1.876667
# 990              2.1250            1.7825           2.436667
#
#      intermediate_automation_risk  automation_risk  automation_risk_score  \
# 879                          0.42             0.42                   52.0
# 880                          0.46             0.46                   56.0
# 881                          0.46             0.46                   56.0
# 882                          0.43             0.43                   53.0
# 883                          0.43             0.43                   53.0
# ..                            ...              ...                    ...
# 986                          0.42             0.42                   52.0
# 987                          0.36             0.36                   46.0
# 988                          0.35             0.35                   45.0
# 989                          0.43             0.43                   53.0
# 990                          0.40             0.40                   50.0
#
#      missing_job  adoption_rate
# 879         True       0.343750
# 880         True       0.469697
# 881         True       0.433333
# 882         True       0.388889
# 883         True       0.500000
# ..           ...            ...
# 986         True       0.388889
# 987         True       0.388889
# 988         True       0.333333
# 989         True       0.388889
# 990         True       0.388889
#
# [112 rows x 14 columns]

# %%
skills_combined_df[skills_combined_df['automation_risk'] != skills_combined_df['intermediate_automation_risk']]
# Out:
#     O*NET-SOC Code                                              Title  \
# 35      11-9121.00                          Natural Sciences Managers
# 69      13-1081.01                                Logistics Engineers
# 92      13-2099.01                    Financial Quantitative Analysts
# 94      15-1211.00                          Computer Systems Analysts
# 95      15-1211.01                     Health Informatics Specialists
# ..             ...                                                ...
# 904     19-2099.00                     Physical Scientists, All Other
# 934     29-1242.00              Orthopedic Surgeons, Except Pediatric
# 935     29-1243.00                                 Pediatric Surgeons
# 936     29-1249.00                                Surgeons, All Other
# 966     43-9199.00  Office and Administrative Support Workers, All...
#
#      basic_skills  cognitive_skills  social_skills  operations_skills  \
# 35         3.9400          3.697143       3.230000             2.0300
# 69         3.9675          3.608571       3.083333             2.3125
# 92         3.7500          3.357143       2.980000             1.4975
# 94         3.7525          3.410000       2.895000             2.9050
# 95         4.0950          3.695714       3.186667             2.2475
# ..            ...               ...            ...                ...
# 904        3.9100          3.518571       2.813333             2.0950
# 934        4.0925          3.661429       3.666667             2.5925
# 935        4.0925          3.661429       3.666667             2.5925
# 936        4.0925          3.661429       3.666667             2.5925
# 966        3.5025          3.142857       2.793333             1.4075
#
#      maintenance_skills  technical_skills  management_skills  \
# 35               1.0300            2.9350           3.080000
# 69               1.3775            2.9375           3.395000
# 92               1.0000            2.6900           2.833333
# 94               1.9075            2.8450           2.936667
# 95               1.2825            2.6875           3.020000
# ..                  ...               ...                ...
# 904              1.1250            3.2225           2.771667
# 934              1.4700            2.6900           2.873333
# 935              1.4700            2.6900           2.873333
# 936              1.4700            2.6900           2.873333
# 966              1.0000            2.8450           2.271667
#
#      intermediate_automation_risk  automation_risk  automation_risk_score  \
# 35                           0.52         0.539570                   63.6
# 69                           0.47         0.430260                   53.0
# 92                           0.54         0.632993                   71.7
# 94                           0.45         0.667529                   74.5
# 95                           0.48         0.673529                   74.9
# ..                            ...              ...                    ...
# 904                          0.57         0.600911                   69.1
# 934                          0.43         0.175086                   28.9
# 935                          0.43         0.175086                   28.9
# 936                          0.43         0.175086                   28.9
# 966                          0.59         0.535642                   63.2
#
#      missing_job  adoption_rate
# 35         False       0.655172
# 69         False       0.448980
# 92         False       0.777778
# 94         False       0.395498
# 95         False       0.412698
# ..           ...            ...
# 904         True       0.388889
# 934         True       0.250000
# 935         True       0.250000
# 936         True       0.388889
# 966         True       0.388889
#
# [99 rows x 14 columns]

# %%
print(f"median: {skills_combined_df['automation_risk_score'].median()}")
print(f"std: {skills_combined_df['automation_risk_score'].std()}")
print(f"min: {skills_combined_df['automation_risk_score'].min()}")
print(f"max: {skills_combined_df['automation_risk_score'].max()}")
print(f"iqr: {skills_combined_df['automation_risk_score'].quantile(0.75) - skills_combined_df['automation_risk_score'].quantile(0.25)}")
print(f"mean: {skills_combined_df['automation_risk_score'].mean()}")
# Out:
# median: 54.0
# std: 6.43425165416634
# min: 28.9
# max: 81.8
# iqr: 7.899999999999999
# mean: 53.854389505549946

# %% [markdown]
# ```
# Prior without automation_susceptibility_norm
#
# median: 54.0
# std: 5.709221485812173
# min: 38.2
# max: 71.5
# iqr: 7.899999999999999
# mean: 53.725142207053466
# ```

# %%
skills_combined_df.sort_values(by='automation_risk_score', ascending=False, inplace=True)

# %%
skills_combined_df[:40][['O*NET-SOC Code', 'Title', 'automation_risk_score', 'automation_risk', 'basic_skills', 'cognitive_skills', 'social_skills', 'operations_skills', 'maintenance_skills', 'technical_skills', 'management_skills']]
# Out:
#     O*NET-SOC Code                                              Title  \
# 107     15-1253.00    Software Quality Assurance Analysts and Testers
# 893     15-1252.00                                Software Developers
# 106     15-1251.00                               Computer Programmers
# 104     15-1243.01                       Data Warehousing Specialists
# 108     15-1254.00                                     Web Developers
# 103     15-1243.00                                Database Architects
# 894     15-1255.00                Web and Digital Interface Designers
# 109     15-1255.01                               Video Game Designers
# 102     15-1242.00                            Database Administrators
# 95      15-1211.01                     Health Informatics Specialists
# 94      15-1211.00                          Computer Systems Analysts
# 187     19-1029.04                                         Biologists
# 92      13-2099.01                    Financial Quantitative Analysts
# 892     13-2099.00                   Financial Specialists, All Other
# 902     19-1029.00                   Biological Scientists, All Other
# 184     19-1029.01                          Bioinformatics Scientists
# 186     19-1029.03                                        Geneticists
# 185     19-1029.02                  Molecular and Cellular Biologists
# 97      15-1221.00       Computer and Information Research Scientists
# 205     19-2099.01        Remote Sensing Scientists and Technologists
# 116     15-2021.00                                     Mathematicians
# 904     19-2099.00                     Physical Scientists, All Other
# 100     15-1241.00                        Computer Network Architects
# 121     15-2051.02                             Clinical Data Managers
# 897     15-2099.00        Mathematical Science Occupations, All Other
# 122     15-2099.01                         Bioinformatics Technicians
# 105     15-1244.00        Network and Computer Systems Administrators
# 230     19-4061.00                 Social Science Research Assistants
# 111     15-1299.02  Geographic Information Systems Technologists a...
# 118     15-2041.00                                      Statisticians
# 119     15-2041.01                                   Biostatisticians
# 195     19-2012.00                                         Physicists
# 208     19-3022.00                                 Survey Researchers
# 217     19-3092.00                                        Geographers
# 558     43-3051.00                     Payroll and Timekeeping Clerks
# 166     17-3022.00    Civil Engineering Technologists and Technicians
# 260     25-1022.00       Mathematical Science Teachers, Postsecondary
# 128     17-2011.00                                Aerospace Engineers
# 194     19-2011.00                                        Astronomers
# 207     19-3011.01                           Environmental Economists
#
#      automation_risk_score  automation_risk  basic_skills  cognitive_skills  \
# 107                   81.8         0.775459        3.8775          3.302857
# 893                   78.5         0.723413        3.3750          3.195714
# 106                   78.5         0.723413        3.3750          3.195714
# 104                   77.2         0.705171        3.5025          3.161429
# 108                   77.0         0.701428        3.3725          3.392857
# 103                   76.8         0.699171        3.5000          3.430000
# 894                   76.3         0.692879        3.5000          3.355714
# 109                   76.3         0.692879        3.5000          3.355714
# 102                   75.2         0.677884        3.5325          3.482857
# 95                    74.9         0.673529        4.0950          3.695714
# 94                    74.5         0.667529        3.7525          3.410000
# 187                   71.9         0.634811        4.0000          3.375714
# 92                    71.7         0.632993        3.7500          3.357143
# 892                   71.7         0.632993        3.7500          3.357143
# 902                   71.4         0.628811        4.0000          3.427143
# 184                   71.4         0.628811        4.0000          3.427143
# 186                   71.1         0.624811        4.0625          3.678571
# 185                   70.9         0.622811        4.1575          3.821429
# 97                    69.2         0.602363        3.5950          3.534286
# 205                   69.1         0.600911        3.9100          3.518571
# 116                   69.1         0.601595        3.5650          3.535714
# 904                   69.1         0.600911        3.9100          3.518571
# 100                   68.9         0.598435        3.7175          3.428571
# 121                   68.9         0.599127        3.8475          3.374286
# 897                   67.5         0.583059        3.5325          3.160000
# 122                   67.5         0.583059        3.5325          3.160000
# 105                   67.4         0.581721        3.5325          3.464286
# 230                   66.4         0.570000        3.7200          3.035714
# 111                   66.4         0.570000        3.5000          2.945714
# 118                   66.3         0.569202        3.8775          3.430000
# 119                   65.8         0.563202        3.9400          3.625714
# 195                   65.6         0.561269        4.0925          3.714286
# 208                   64.6         0.550000        4.0000          3.285714
# 217                   64.6         0.550000        3.9975          3.337143
# 558                   64.6         0.550000        3.4675          2.607143
# 166                   64.6         0.550000        3.5325          3.017143
# 260                   64.6         0.550000        4.0000          3.482857
# 128                   64.2         0.546471        3.9100          3.768571
# 194                   63.9         0.542216        4.0925          3.570000
# 207                   63.6         0.540000        3.9050          3.410000
#
#      social_skills  operations_skills  maintenance_skills  technical_skills  \
# 107       2.603333             2.7850              1.4675            2.9350
# 893       2.601667             2.2800              1.0625            3.3425
# 106       2.601667             2.2800              1.0625            3.3425
# 104       2.788333             2.0950              1.1850            2.8125
# 108       2.856667             2.1850              1.3125            2.8425
# 103       2.896667             1.9375              1.3700            2.8150
# 894       2.958333             1.5925              1.0600            2.8150
# 109       2.958333             1.5925              1.0600            2.8150
# 102       2.730000             2.3125              1.2500            2.6900
# 95        3.186667             2.2475              1.2825            2.6875
# 94        2.895000             2.9050              1.9075            2.8450
# 187       2.935000             2.0300              1.0625            3.2175
# 92        2.980000             1.4975              1.0000            2.6900
# 892       2.980000             1.4975              1.0000            2.6900
# 902       2.960000             1.9050              1.1250            2.9050
# 184       2.960000             1.9050              1.1250            2.9050
# 186       3.248333             2.2800              1.0300            2.9400
# 185       3.143333             2.5950              1.2200            3.1550
# 97        2.833333             2.3450              1.2800            3.3100
# 205       2.813333             2.0950              1.1250            3.2225
# 116       2.500000             1.2800              1.0000            3.1850
# 904       2.813333             2.0950              1.1250            3.2225
# 100       3.083333             2.9375              2.1850            3.0300
# 121       2.916667             1.9975              1.2200            2.7200
# 897       2.731667             1.7775              1.0900            2.9350
# 122       2.731667             1.7775              1.0900            2.9350
# 105       2.855000             3.3450              2.8150            2.9050
# 230       2.606667             1.9975              1.0950            2.6850
# 111       2.645000             1.5300              1.0625            2.4700
# 118       2.543333             1.4700              1.0000            3.2500
# 119       2.750000             1.3725              1.1250            3.4050
# 195       3.123333             2.1550              1.2500            3.7500
# 208       2.936667             1.4675              1.0000            2.5950
# 217       2.915000             1.2800              1.0300            2.5025
# 558       2.480000             1.3750              1.0000            1.8775
# 166       2.668333             2.0925              1.0300            2.5000
# 260       3.020000             1.1875              1.0000            2.5000
# 128       3.041667             2.3450              1.0625            3.3125
# 194       2.956667             1.7200              1.2800            3.1550
# 207       2.916667             1.2200              1.0000            2.5025
#
#      management_skills
# 107           2.415000
# 893           2.706667
# 106           2.706667
# 104           2.563333
# 108           2.500000
# 103           2.750000
# 894           2.753333
# 109           2.753333
# 102           2.583333
# 95            3.020000
# 94            2.936667
# 187           2.645000
# 92            2.833333
# 892           2.833333
# 902           2.813333
# 184           2.813333
# 186           2.830000
# 185           2.936667
# 97            3.063333
# 205           2.771667
# 116           2.435000
# 904           2.771667
# 100           3.063333
# 121           2.751667
# 897           2.518333
# 122           2.518333
# 105           3.083333
# 230           2.481667
# 111           2.311667
# 118           2.480000
# 119           2.581667
# 195           2.875000
# 208           2.623333
# 217           2.561667
# 558           1.875000
# 166           2.500000
# 260           2.393333
# 128           2.751667
# 194           2.730000
# 207           2.893333

# %%
skills_importance_df[
    skills_importance_df['O*NET-SOC Code'].isin(['31-9011.00', '29-1022.00', '27-2011.00' , '45-2021.00'])
]
# Out:
# Element Name O*NET-SOC Code                            Title  Active Learning  \
# 327              27-2011.00                           Actors             2.62
# 356              29-1022.00  Oral and Maxillofacial Surgeons             3.88
# 443              31-9011.00               Massage Therapists             3.00
# 604              45-2021.00                  Animal Breeders             3.00
#
# Element Name  Active Listening  Complex Problem Solving  Coordination  \
# 327                       3.75                     2.88          2.88
# 356                       3.88                     4.12          3.62
# 443                       3.62                     3.00          2.38
# 604                       3.00                     3.00          2.50
#
# Element Name  Critical Thinking  Equipment Maintenance  Equipment Selection  \
# 327                        3.00                   1.00                 1.00
# 356                        4.00                   1.88                 2.12
# 443                        3.00                   1.00                 1.00
# 604                        3.25                   1.00                 1.38
#
# Element Name  Installation  Instructing  Judgment and Decision Making  \
# 327                    1.0         2.75                          2.88
# 356                    1.0         2.88                          4.12
# 443                    1.0         2.25                          3.12
# 604                    1.0         1.88                          3.00
#
# Element Name  Learning Strategies  Management of Financial Resources  \
# 327                          2.75                               1.00
# 356                          2.88                               2.00
# 443                          2.75                               1.38
# 604                          2.12                               2.12
#
# Element Name  Management of Material Resources  \
# 327                                       1.00
# 356                                       2.00
# 443                                       1.62
# 604                                       2.00
#
# Element Name  Management of Personnel Resources  Mathematics  Monitoring  \
# 327                                        2.38         1.00        3.00
# 356                                        2.75         2.62        3.88
# 443                                        1.75         2.00        3.00
# 604                                        2.00         2.12        3.00
#
# Element Name  Negotiation  Operation and Control  Operations Analysis  \
# 327                  2.50                   1.00                 1.75
# 356                  2.62                   2.88                 3.12
# 443                  2.00                   1.00                 1.62
# 604                  1.75                   2.62                 1.62
#
# Element Name  Operations Monitoring  Persuasion  Programming  \
# 327                            1.25        2.50          1.0
# 356                            2.75        2.75          1.5
# 443                            1.38        2.00          1.0
# 604                            2.88        2.38          1.5
#
# Element Name  Quality Control Analysis  Reading Comprehension  Repairing  \
# 327                               1.00                   3.88       1.00
# 356                               2.75                   4.00       1.88
# 443                               1.75                   3.00       1.00
# 604                               2.62                   2.88       1.00
#
# Element Name  Science  Service Orientation  Social Perceptiveness  Speaking  \
# 327              1.50                 2.12                   3.75      3.88
# 356              3.50                 3.25                   3.75      3.88
# 443              1.75                 3.25                   3.25      3.62
# 604              3.00                 2.38                   2.62      3.00
#
# Element Name  Systems Analysis  Systems Evaluation  Technology Design  \
# 327                       2.00                2.00               1.25
# 356                       3.25                3.00               2.00
# 443                       2.12                2.25               1.75
# 604                       2.38                2.12               1.25
#
# Element Name  Time Management  Troubleshooting  Writing normalized_major_code  \
# 327                      3.00             1.00     2.88                    27
# 356                      3.38             1.88     3.50                    29
# 443                      2.88             1.38     3.00                    31
# 604                      2.75             2.00     2.75                    45
#
# Element Name normalized_minor_code
# 327                            272
# 356                            291
# 443                            319
# 604                            452

# %%
skills_combined_df.to_csv('../v2_assets/skills_based_risk.csv', index=False)

# %%
skills_combined_df.shape
# Out:
# (991, 14)

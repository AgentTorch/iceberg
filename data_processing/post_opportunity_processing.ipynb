# %%
import pandas as pd

state = 'Tennessee'
national_detailed_file_path = '../generation/national_summary_detailed.csv'
national_detailed_df = pd.read_csv(national_detailed_file_path)
national_detailed_df = national_detailed_df[national_detailed_df['AREA_TITLE'] == state]

# %%
import pandas as pd

opportunity_df_v1 = pd.read_csv("../data_v2/opportunity_jobs_v1.csv")
opportunity_df_v2 = pd.read_csv("../data_v2/opportunity_jobs_v2.csv")

# %%
opportunity_df_v1 = opportunity_df_v1.rename(columns={'O*NET-SOC Code': 'OCC_CODE'})
opportunity_df_v1['OCC_CODE'] = opportunity_df_v1['OCC_CODE'].apply(lambda x: x.split('.')[0])

# %%
opportunity_df_v2 = opportunity_df_v2.rename(columns={'O*NET-SOC Code': 'OCC_CODE'})
opportunity_df_v2['OCC_CODE'] = opportunity_df_v2['OCC_CODE'].apply(lambda x: x.split('.')[0])
opportunity_df_v2 = opportunity_df_v2[opportunity_df_v2['AI_Transformation_Classification'] == 'High Transformation Potential']

# %%
opportunity_df_v1
# Out:
#     OCC_CODE                                              Title  \
# 0    25-1072    Nursing Instructors and Teachers, Postsecondary
# 1    17-3026  Nanotechnology Engineering Technologists and T...
# 2    29-1031                       Dietitians and Nutritionists
# 3    43-3031       Bookkeeping, Accounting, and Auditing Clerks
# 4    47-4011               Construction and Building Inspectors
# ..       ...                                                ...
# 524  33-9091                       Crossing Guards and Flaggers
# 525  47-3016                                   Helpers--Roofers
# 526  49-9043                     Maintenance Workers, Machinery
# 527  31-1132                                          Orderlies
# 528  43-1011  First-Line Supervisors of Office and Administr...
#
#      technical_composition  cognitive_skills  social_skills  \
# 0                 0.155773          3.662857       3.520000
# 1                 0.155766          3.162857       2.893333
# 2                 0.155759          3.750000       3.646667
# 3                 0.155631          2.572857       2.521667
# 4                 0.155430          3.108571       2.936667
# ..                     ...               ...            ...
# 524               0.116688          2.305714       2.436667
# 525               0.116584          2.445714       2.498333
# 526               0.116552          2.625714       2.371667
# 527               0.116547          2.228571       2.731667
# 528               0.116538          3.537143       3.768333
#
#      operations_skills  maintenance_skills  management_skills  \
# 0               1.9050              1.0625           2.748333
# 1               2.9075              1.9675           2.605000
# 2               1.8150              1.0000           3.000000
# 3               1.2150              1.0000           2.185000
# 4               2.3775              1.0000           2.626667
# ..                 ...                 ...                ...
# 524             1.3125              1.0000           1.688333
# 525             2.4100              2.3425           2.143333
# 526             3.5600              3.2825           2.145000
# 527             1.9400              1.0925           1.710000
# 528             2.0625              1.0000           3.145000
#
#      technical_skills
# 0              2.3800
# 1              2.4975
# 2              2.4375
# 3              1.7500
# 4              2.2175
# ..                ...
# 524            1.1550
# 525            1.5625
# 526            1.8450
# 527            1.2800
# 528            1.7825
#
# [529 rows x 9 columns]

# %%
merged_opportunity_df_v2 = opportunity_df_v2.merge(
    national_detailed_df,
    on='OCC_CODE',
    how='left'
)

# %%
merged_opportunity_df_v1 = opportunity_df_v1.merge(
    national_detailed_df,
    on='OCC_CODE',
    how='left'
)

# %%
merged_opportunity_df_v2[merged_opportunity_df_v2['Tech_Stratum']=='Medium-Tech'].sort_values(by='TOT_EMP', ascending=False)[['OCC_CODE', 'Title', 'economic_value', 'TOT_EMP']][:10]
# Out:
#     OCC_CODE                                              Title  \
# 109  41-2031                                Retail Salespersons
# 21   11-1021                    General and Operations Managers
# 10   43-1011  First-Line Supervisors of Office and Administr...
# 50   35-1012  First-Line Supervisors of Food Preparation and...
# 79   13-1071                        Human Resources Specialists
# 85   41-4012  Sales Representatives, Wholesale and Manufactu...
# 52   11-9199                                Compliance Managers
# 69   47-1011                 Solar Energy Installation Managers
# 64   33-3051               Police and Sheriff's Patrol Officers
# 110  39-9011                                  Childcare Workers
#
#      economic_value  TOT_EMP
# 109    2.914111e+09  84910.0
# 21     8.559237e+09  70580.0
# 10     3.384595e+09  50660.0
# 50     1.126686e+09  27440.0
# 79     1.421116e+09  21010.0
# 85     1.332856e+09  19790.0
# 52     1.658437e+09  16980.0
# 69     1.085950e+09  15280.0
# 64     6.857651e+08  12730.0
# 110    3.193176e+08  11620.0

# %%
merged_opportunity_df_v2[merged_opportunity_df_v2['Tech_Stratum']=='Medium-Tech'].sort_values(by='economic_value', ascending=False)[['OCC_CODE', 'Title', 'economic_value', 'TOT_EMP']][:10]
# Out:
#     OCC_CODE                                              Title  \
# 21   11-1021                    General and Operations Managers
# 10   43-1011  First-Line Supervisors of Office and Administr...
# 109  41-2031                                Retail Salespersons
# 52   11-9199                                Compliance Managers
# 124  11-2022                                     Sales Managers
# 4    23-1011                                            Lawyers
# 79   13-1071                        Human Resources Specialists
# 85   41-4012  Sales Representatives, Wholesale and Manufactu...
# 105  11-1011                                   Chief Executives
# 50   35-1012  First-Line Supervisors of Food Preparation and...
#
#      economic_value  TOT_EMP
# 21     8.559237e+09  70580.0
# 10     3.384595e+09  50660.0
# 109    2.914111e+09  84910.0
# 52     1.658437e+09  16980.0
# 124    1.571872e+09  10610.0
# 4      1.454838e+09   9380.0
# 79     1.421116e+09  21010.0
# 85     1.332856e+09  19790.0
# 105    1.295165e+09   5810.0
# 50     1.126686e+09  27440.0

# %%
merged_opportunity_df_v2[merged_opportunity_df_v2['Tech_Stratum']=='Low-Tech'].sort_values(by='TOT_EMP', ascending=False)[['OCC_CODE', 'Title', 'economic_value', 'TOT_EMP']][:10]
# Out:
#     OCC_CODE                                              Title  \
# 51   51-1011  First-Line Supervisors of Production and Opera...
# 12   11-9199                           Loss Prevention Managers
# 75   47-1011  First-Line Supervisors of Construction Trades ...
# 43   39-9011                                            Nannies
# 74   13-1041                                Compliance Officers
# 72   33-3012                  Correctional Officers and Jailers
# 30   11-3012                   Administrative Services Managers
# 117  27-2022                                 Coaches and Scouts
# 45   25-2011       Preschool Teachers, Except Special Education
# 5    33-1012    First-Line Supervisors of Police and Detectives
#
#      economic_value  TOT_EMP
# 51     1.210298e+09  18430.0
# 12     1.658437e+09  16980.0
# 75     1.085950e+09  15280.0
# 43     3.193176e+08  11620.0
# 74     5.453127e+08   8490.0
# 72     3.905150e+08   8300.0
# 30     1.091710e+09   8230.0
# 117    2.752694e+08   5570.0
# 45     2.143836e+08   5270.0
# 5      3.696128e+08   5120.0

# %%
merged_opportunity_df_v2[merged_opportunity_df_v2['Tech_Stratum']=='Low-Tech'].sort_values(by='economic_value', ascending=False)[['OCC_CODE', 'Title', 'economic_value', 'TOT_EMP']][:10]
# Out:
#     OCC_CODE                                              Title  \
#